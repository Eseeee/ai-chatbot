# %% [markdown]
# in Sec
# öffnungszeiten
# 18.77 Währinger
# 18.96 Seiler
# 23.62 MariaH
# 28.44 Hütteldorfer straße
# 26.45 Jörgerstraße
#
# Telefonnummer
# 19.90 Seilergasse
# 20.35 Währingerstaße
# 17.91 Mariahilfer
# 12.21 Hütteldorfer Straße
# 19.41 Jörgerstraße

# %%
import matplotlib.pyplot as plt
names = ['Prompt 1', 'Prompt 2', 'Prompt 3', "Prompt 4", "Prompt 5", "Prompt 6", "Prompt 7", "Prompt 8", "Prompt 9", "Prompt 10", ]
values = [18.77, 18.96, 23.62, 28.44, 26.45, 19.90, 20.35, 17.91, 12.21, 19.41]

plt.figure(figsize=(50, 3))

ax=plt.subplot(131)
ax.set_ylim(ymin=0,ymax=35)
ax.set_ylabel('Runtime in Seconds')
ax.set_xlabel('Prompts')
plt.plot(names, values)
